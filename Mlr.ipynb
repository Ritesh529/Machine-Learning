# %%
##for reading data through read.csv
import pandas as pd

#for plotiing of barplot,boxplot
import matplotlib.pyplot as plt


#for graphical representation
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
#Load the data through read_csv function
cars=pd.read_csv("C:\\Users\\admin\\ML\\MLR-master\\cars.csv")

# %%
cars.head()
# Out:
#     mpg   cylinders  cubicinches   hp   year
# 0  14.0           8          350  165   1972
# 1  31.9           4           89   71   1980
# 2  17.0           8          302  140   1971
# 3  15.0           8          400  150   1971
# 4  30.5           4           98   63   1978

# %%
cars.shape
# Out:
# (261, 5)

# %%
cars.columns
# Out:
# Index(['mpg', ' cylinders', ' cubicinches', ' hp', ' year'], dtype='object')

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
import seaborn as sns
sns.pairplot(cars.iloc[:,:])
